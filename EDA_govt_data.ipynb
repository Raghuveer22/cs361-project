# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)
dataset=pd.read_csv('govt_data_Final.csv')
x=dataset.copy()
x=x.drop(columns=['Type'])
print(dataset.shape)
# Out:
# (2685, 18)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Get the data types of each column
data_types = dataset.dtypes

# Count the unique data types
unique_data_types = data_types.unique()
num_unique_data_types = len(unique_data_types)

print("Number of unique data types:", num_unique_data_types)
# Out:
# Number of unique data types: 2

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Print data types of all columns
print(dataset.dtypes)
# Out:
# Type                 object
# Temp_min            float64
# Temp_max            float64
# DisO2_min           float64
# DisO2_max           float64
# pH_min              float64
# pH_max              float64
# Conductivity_min    float64
# Conductivity_max    float64
# N_min               float64
# N_max               float64
# Fecal_Col_min       float64
# Fecal_Col_max       float64
# Total_Coli_min      float64
# Total_Coli_max      float64
# Fecal_Strep_min     float64
# Fecal_Strep_max     float64
# BOD_avg             float64
# dtype: object

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Drop the 'Type' column
# df = dataset.drop(columns=['Type'])

# Plot kernel density graphs for all remaining columns
for column in df.columns:
    plt.figure(figsize=(8, 4))  # Set the figure size
    sns.kdeplot(x[column], fill=True)  # Plot the KDE plot
    plt.title(f'Kernel Density Estimation for {column}')  # Set the title
    plt.xlabel(column)  # Set the x-axis label
    plt.ylabel('Density')  # Set the y-axis label
    plt.show()  # Show the plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')



# Plot boxplots for all remaining columns
for column in x.columns:
    plt.figure(figsize=(8, 4))  # Set the figure size
    sns.boxplot(x=x[column])  # Plot the boxplot
    plt.title(f'Boxplot for {column}')  # Set the title
    plt.xlabel(column)  # Set the x-axis label
    plt.show()  # Show the plot

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Check number of null values in each column
null_counts = dataset.isnull().sum()
print("Number of null values in each column:")
print(null_counts)
# Out:
# Number of null values in each column:
# Type                   0
# Temp_min              44
# Temp_max              44
# DisO2_min              6
# DisO2_max              6
# pH_min                 1
# pH_max                 0
# Conductivity_min      64
# Conductivity_max      64
# N_min                250
# N_max                249
# Fecal_Col_min        260
# Fecal_Col_max        262
# Total_Coli_min       267
# Total_Coli_max       269
# Fecal_Strep_min     1664
# Fecal_Strep_max     1664
# BOD_avg                4
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Count missing values in each column
missing_counts = dataset.isnull().sum()

# Plot bar graph for missing values of each column
plt.figure(figsize=(10, 6))
missing_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd


df = dataset.drop(columns=['Fecal_Strep_min', 'Fecal_Strep_max'], errors='ignore')

# %%
# Save the modified DataFrame to a new CSV file
df.to_csv('modified_data.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)
df=pd.read_csv('modified_data.csv')
print(dataset.shape)
# Out:
# (2685, 18)

# %%
import pandas as pd

# Remove rows with null values in the 'BOD_avg' column
df = df.dropna(subset=['BOD_avg'])

# Now your DataFrame 'df' doesn't contain rows with null values in the 'BOD_avg' column

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Check number of null values in each column
null_counts = df.isnull().sum()
print("Number of null values in each column:")
print(null_counts)
# Out:
# Number of null values in each column:
# Type                  0
# Temp_min             44
# Temp_max             44
# DisO2_min             2
# DisO2_max             2
# pH_min                1
# pH_max                0
# Conductivity_min     64
# Conductivity_max     64
# N_min               247
# N_max               246
# Fecal_Col_min       258
# Fecal_Col_max       260
# Total_Coli_min      265
# Total_Coli_max      267
# BOD_avg               0
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


x=df.drop(columns=['Type'])
correlation_matrix = x.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix (Excluding "Type" column)')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

column_means = df.drop(columns=['Type']).mean()

# Replace null values with column means
df.fillna(column_means, inplace=True)

null_counts = df.isnull().sum()
print("Number of null values in each column:")
print(null_counts)
# Out:
# Number of null values in each column:
# Type                0
# Temp_min            0
# Temp_max            0
# DisO2_min           0
# DisO2_max           0
# pH_min              0
# pH_max              0
# Conductivity_min    0
# Conductivity_max    0
# N_min               0
# N_max               0
# Fecal_Col_min       0
# Fecal_Col_max       0
# Total_Coli_min      0
# Total_Coli_max      0
# BOD_avg             0
# dtype: int64

# %%
x=df.drop(columns=['Type'])
correlation_matrix = x.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix (After Replacing Null Values with Column Means)')
plt.show()

# %%
df.head()
# Out:
#     Type  Temp_min  Temp_max  DisO2_min  DisO2_max  pH_min  pH_max  \
# 0  RIVER      17.0      33.0        5.4        9.2     7.4     8.3
# 1  RIVER      14.0      29.0        5.2        9.0     7.4     8.2
# 2  RIVER      10.0      28.0        6.5       10.4     7.2     8.4
# 3  RIVER      14.0      30.0        6.2       10.4     7.1     8.1
# 4  RIVER      17.0      29.0        2.5        8.9     7.1     7.9
#
#    Conductivity_min  Conductivity_max  N_min  N_max  Fecal_Col_min  \
# 0             230.0             495.0    0.3   0.77        11000.0
# 1             191.0             520.0    0.3   1.65         2300.0
# 2             191.0             495.0    0.3   0.57          780.0
# 3             190.0             516.0    0.3   1.20         1300.0
# 4             164.0             632.0    0.3   0.49         2700.0
#
#    Fecal_Col_max  Total_Coli_min  Total_Coli_max  BOD_avg
# 0       160000.0         28000.0        160000.0     2.15
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Count the occurrences of each type
type_counts = df['Type'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 6))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
df.head()
# Out:
#     Type  Temp_min  Temp_max  DisO2_min  DisO2_max  pH_min  pH_max  \
# 0  RIVER      17.0      33.0        5.4        9.2     7.4     8.3
# 1  RIVER      14.0      29.0        5.2        9.0     7.4     8.2
# 2  RIVER      10.0      28.0        6.5       10.4     7.2     8.4
# 3  RIVER      14.0      30.0        6.2       10.4     7.1     8.1
# 4  RIVER      17.0      29.0        2.5        8.9     7.1     7.9
#
#    Conductivity_min  Conductivity_max  N_min  N_max  Fecal_Col_min  \
# 0             230.0             495.0    0.3   0.77        11000.0
# 1             191.0             520.0    0.3   1.65         2300.0
# 2             191.0             495.0    0.3   0.57          780.0
# 3             190.0             516.0    0.3   1.20         1300.0
# 4             164.0             632.0    0.3   0.49         2700.0
#
#    Fecal_Col_max  Total_Coli_min  Total_Coli_max  BOD_avg
# 0       160000.0         28000.0        160000.0     2.15
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Get unique categories in the 'Type' column
categories = df['Type'].unique()

# Create new binary columns for each category
for category in categories:
    df[f'Type_{category}'] = (df['Type'] == category).astype(int)

# Drop the original 'Type' column
x = df.drop(columns=['Type'], inplace=True)

# Now your DataFrame 'df' contains one-hot encoded columns for 'Type'
df.head()
# Out:
#    Temp_min  Temp_max  DisO2_min  DisO2_max  pH_min  pH_max  Conductivity_min  \
# 0      17.0      33.0        5.4        9.2     7.4     8.3             230.0
# 1      14.0      29.0        5.2        9.0     7.4     8.2             191.0
# 2      10.0      28.0        6.5       10.4     7.2     8.4             191.0
# 3      14.0      30.0        6.2       10.4     7.1     8.1             190.0
# 4      17.0      29.0        2.5        8.9     7.1     7.9             164.0
#
#    Conductivity_max  N_min  N_max  Fecal_Col_min  Fecal_Col_max  \
# 0             495.0    0.3   0.77        11000.0       160000.0
# 1             520.0    0.3   1.65         2300.0       160000.0
# 2             495.0    0.3   0.57          780.0       160000.0
# 3             516.0    0.3   1.20         1300.0        35000.0
# 4             632.0    0.3   0.49         2700.0       350000.0
#
#    Total_Coli_min  Total_Coli_max  BOD_avg  Type_RIVER  Type_LAKE   \
# ...

# %%
df.to_csv('cleaned.csv',index=False)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Replace 'df' with the name of your DataFrame

# Load your dataset into a DataFrame (replace 'data.csv' with your actual data file)
# df = pd.read_csv('data.csv')

# Extract 'Type' column

# Calculate mean and standard deviation for each column
means = df.mean()
stds = df.std()

# Standardize each column (except 'Type')
df_scaled = (df - means) / stds

# Concatenate the scaled DataFrame with the 'Type' column


# Now your DataFrame 'df_scaled' contains all columns scaled except 'Type'
df.head()
# Out:
#    Temp_min  Temp_max  DisO2_min  DisO2_max  pH_min  pH_max  Conductivity_min  \
# 0      17.0      33.0        5.4        9.2     7.4     8.3             230.0
# 1      14.0      29.0        5.2        9.0     7.4     8.2             191.0
# 2      10.0      28.0        6.5       10.4     7.2     8.4             191.0
# 3      14.0      30.0        6.2       10.4     7.1     8.1             190.0
# 4      17.0      29.0        2.5        8.9     7.1     7.9             164.0
#
#    Conductivity_max  N_min  N_max  Fecal_Col_min  Fecal_Col_max  \
# 0             495.0    0.3   0.77        11000.0       160000.0
# 1             520.0    0.3   1.65         2300.0       160000.0
# 2             495.0    0.3   0.57          780.0       160000.0
# 3             516.0    0.3   1.20         1300.0        35000.0
# 4             632.0    0.3   0.49         2700.0       350000.0
#
#    Total_Coli_min  Total_Coli_max  BOD_avg  Type_RIVER  Type_LAKE   \
# ...

# %%
df_scaled.head()
# Out:
#    Temp_min  Temp_max  DisO2_min  DisO2_max    pH_min    pH_max  \
# 0 -0.579484  1.085143   0.279164   0.820174  0.538596  0.484127
# 1 -1.158382  0.163558   0.194100   0.734819  0.538596  0.287469
# 2 -1.930246 -0.066838   0.747014   1.332303  0.189813  0.680785
# 3 -1.158382  0.393954   0.619418   1.332303  0.015422  0.090811
# 4 -0.579484  0.163558  -0.954259   0.692142  0.015422 -0.302506
#
#    Conductivity_min  Conductivity_max     N_min     N_max  Fecal_Col_min  \
# 0         -0.181076         -0.214261 -0.395087 -0.371179       0.791197
# 1         -0.206710         -0.209617 -0.395087 -0.289228       0.034830
# 2         -0.206710         -0.214261 -0.395087 -0.389804      -0.097316
# 3         -0.207367         -0.210360 -0.395087 -0.331135      -0.052108
# 4         -0.224457         -0.188814 -0.395087 -0.397254       0.069606
#
#    Fecal_Col_max  Total_Coli_min  Total_Coli_max   BOD_avg  Type_RIVER  \
# ...
